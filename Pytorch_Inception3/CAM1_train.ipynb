# %%
# Params
input_size = (299,299)
batch_size = 100
num_workers = 8
num_classes = 2
learning_rate = 1e-03
epochs = 100

# %%
import torch

print("torch-version:", torch.__version__)
print("Available GPU:", torch.cuda.current_device())
# Out:
# torch-version: 1.1.0
# Available GPU: 0

# %%
from load_MH import *

# 기존 데이터 경로
NORMAL_DIR = '../../snapshots_pureok'
FAULT_DIR = '../../snapshots'
# 추가 데이터 경로
ADD_NORMAL_DIR = '../../snapshots_punch181'
ADD_FAULT_DIR = '../../snapshots_punch181_NG'

train_mhdb = dataset(NORMAL_DIR, FAULT_DIR, ADD_NORMAL_DIR, ADD_FAULT_DIR, input_size, batch_size, num_workers)[:4]
val_mhdb = dataset(NORMAL_DIR, FAULT_DIR, ADD_NORMAL_DIR, ADD_FAULT_DIR, input_size, batch_size, num_workers)[4:8]
test_mhdb = dataset(NORMAL_DIR, FAULT_DIR, ADD_NORMAL_DIR, ADD_FAULT_DIR, input_size, batch_size, num_workers)[8:]

# %%
import torchvision
print("torchvision-version:", torchvision.__version__)

net = torchvision.models.inception_v3(pretrained=False, aux_logits=True, num_classes=num_classes).cuda()
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)
# Out:
# torchvision-version: 0.2.2

# %%
def validation(dataset, model, criterion):
    
    with torch.no_grad():
        model.eval()
        running_loss = 0.0
        for data in dataset:
            images, labels = data
            images = images.cuda()
            labels = labels.cuda().long()

            outputs = model(images)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            
    return running_loss

# %%
import numpy as np

times = 1
aux_loss_weight = 0.4
all_train_loss = []
all_val_loss = []
row = np.arange(epochs)

for epoch in range(epochs):  # loop over the dataset multiple times
    net.train()
    running_loss = 0.0
    for i, data in enumerate(train_mhdb[0]):
        # get the inputs
        inputs, labels = data
        inputs = inputs.cuda()
        labels = labels.cuda().long()
        
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs, aux_outputs = net(inputs) #tuple: (x, aux)
        
        loss1 = criterion(outputs, labels)
        loss2 = criterion(aux_outputs, labels)
        
        loss = loss1 + aux_loss_weight*loss2
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
    if epoch % times == 0:
        print("Epoch:", epoch)
        print("Train Loss:", running_loss / times)
        val_loss = validation(val_mhdb[0], net, criterion)
        print("Val Loss:", val_loss)
        
        name = "CAM1"+"-Epoch-"+"%s"%epoch+"-Loss-"+"%s"%str(val_loss)[:8]+".pth"
        model_path = './saved_models/' + name
        torch.save(net.state_dict(), model_path)
        print("Saved model:", model_path, "\n")
        
        all_train_loss.append(running_loss)
        all_val_loss.append(val_loss)
        running_loss = 0.0

print('\nFinished Training')
# Out:
# Epoch: 0
# Train Loss: 41.62958109378815
# Val Loss: 5.47422730922699
# Saved model: ./saved_models/CAM1-Epoch-0-Loss-5.474227.pth
#
# Epoch: 1
# Train Loss: 26.353923559188843
# Val Loss: 3.618184447288513
# Saved model: ./saved_models/CAM1-Epoch-1-Loss-3.618184.pth
#
# Epoch: 2
# Train Loss: 20.247330129146576
# Val Loss: 2.2580440044403076
# Saved model: ./saved_models/CAM1-Epoch-2-Loss-2.258044.pth
#
# Epoch: 3
# Train Loss: 18.16564428806305
# Val Loss: 6.65266552567482
# Saved model: ./saved_models/CAM1-Epoch-3-Loss-6.652665.pth
#
# Epoch: 4
# Train Loss: 14.608501702547073
# Val Loss: 2.0123835504055023
# Saved model: ./saved_models/CAM1-Epoch-4-Loss-2.012383.pth
#
# Epoch: 5
# Train Loss: 11.963477104902267
# Val Loss: 1.4642286449670792
# Saved model: ./saved_models/CAM1-Epoch-5-Loss-1.464228.pth
#
# Epoch: 6
# Train Loss: 10.882840320467949
# Val Loss: 2.0105979442596436
# Saved model: ./saved_models/CAM1-Epoch-6-Loss-2.010597.pth
#
# Epoch: 7
# Train Loss: 10.531130641698837
# Val Loss: 2.9552521109580994
# Saved model: ./saved_models/CAM1-Epoch-7-Loss-2.955252.pth
#
# Epoch: 8
# Train Loss: 11.748330026865005
# Val Loss: 1.7916037440299988
# Saved model: ./saved_models/CAM1-Epoch-8-Loss-1.791603.pth
#
# Epoch: 9
# Train Loss: 10.651126474142075
# Val Loss: 1.4411143213510513
# Saved model: ./saved_models/CAM1-Epoch-9-Loss-1.441114.pth
#
# Epoch: 10
# Train Loss: 10.440304964780807
# Val Loss: 1.8458250164985657
# Saved model: ./saved_models/CAM1-Epoch-10-Loss-1.845825.pth
#
# Epoch: 11
# Train Loss: 10.188577353954315
# Val Loss: 1.6909591555595398
# Saved model: ./saved_models/CAM1-Epoch-11-Loss-1.690959.pth
#
# Epoch: 12
# Train Loss: 9.22495485842228
# Val Loss: 1.6862719357013702
# Saved model: ./saved_models/CAM1-Epoch-12-Loss-1.686271.pth
#
# Epoch: 13
# Train Loss: 8.803341686725616
# Val Loss: 2.0071456730365753
# Saved model: ./saved_models/CAM1-Epoch-13-Loss-2.007145.pth
#
# Epoch: 14
# Train Loss: 10.026430308818817
# Val Loss: 5.988241523504257
# Saved model: ./saved_models/CAM1-Epoch-14-Loss-5.988241.pth
#
# Epoch: 15
# Train Loss: 9.366659983992577
# Val Loss: 2.2213829159736633
# Saved model: ./saved_models/CAM1-Epoch-15-Loss-2.221382.pth
#
# Epoch: 16
# Train Loss: 8.491981074213982
# Val Loss: 2.0902319252490997
# Saved model: ./saved_models/CAM1-Epoch-16-Loss-2.090231.pth
#
# Epoch: 17
# Train Loss: 8.502426087856293
# Val Loss: 1.5220504403114319
# Saved model: ./saved_models/CAM1-Epoch-17-Loss-1.522050.pth
#
# Epoch: 18
# Train Loss: 7.755366861820221
# Val Loss: 7.544927537441254
# Saved model: ./saved_models/CAM1-Epoch-18-Loss-7.544927.pth
#
# Epoch: 19
# Train Loss: 8.172517478466034
# Val Loss: 1.384169027209282
# Saved model: ./saved_models/CAM1-Epoch-19-Loss-1.384169.pth
#
# Epoch: 20
# Train Loss: 8.416435211896896
# Val Loss: 1.3671806678175926
# Saved model: ./saved_models/CAM1-Epoch-20-Loss-1.367180.pth
#
# Epoch: 21
# Train Loss: 8.209069028496742
# Val Loss: 2.2724186778068542
# Saved model: ./saved_models/CAM1-Epoch-21-Loss-2.272418.pth
#
# Epoch: 22
# Train Loss: 7.960529670119286
# Val Loss: 1.8514282703399658
# Saved model: ./saved_models/CAM1-Epoch-22-Loss-1.851428.pth
#
# Epoch: 23
# Train Loss: 10.260138049721718
# Val Loss: 2.752182960510254
# Saved model: ./saved_models/CAM1-Epoch-23-Loss-2.752182.pth
#
# Epoch: 24
# Train Loss: 8.5683021992445
# Val Loss: 1.993760272860527
# Saved model: ./saved_models/CAM1-Epoch-24-Loss-1.993760.pth
#
# Epoch: 25
# Train Loss: 8.421004593372345
# Val Loss: 1.6769866347312927
# Saved model: ./saved_models/CAM1-Epoch-25-Loss-1.676986.pth
#
# Epoch: 26
# Train Loss: 7.988886624574661
# Val Loss: 1.9254776686429977
# Saved model: ./saved_models/CAM1-Epoch-26-Loss-1.925477.pth
#
# Epoch: 27
# Train Loss: 7.084881141781807
# Val Loss: 2.006707042455673
# Saved model: ./saved_models/CAM1-Epoch-27-Loss-2.006707.pth
#
# Epoch: 28
# Train Loss: 7.250459864735603
# Val Loss: 1.596297949552536
# Saved model: ./saved_models/CAM1-Epoch-28-Loss-1.596297.pth
#
# Epoch: 29
# Train Loss: 8.47505547106266
# Val Loss: 3.294454902410507
# Saved model: ./saved_models/CAM1-Epoch-29-Loss-3.294454.pth
#
# Epoch: 30
# Train Loss: 7.466954067349434
# Val Loss: 2.1060721278190613
# Saved model: ./saved_models/CAM1-Epoch-30-Loss-2.106072.pth
#
# Epoch: 31
# Train Loss: 7.320679277181625
# Val Loss: 1.7994590103626251
# Saved model: ./saved_models/CAM1-Epoch-31-Loss-1.799459.pth
#
# Epoch: 32
# Train Loss: 6.857536435127258
# Val Loss: 1.5967482551932335
# Saved model: ./saved_models/CAM1-Epoch-32-Loss-1.596748.pth
#
# Epoch: 33
# Train Loss: 6.765734642744064
# Val Loss: 1.6533836126327515
# Saved model: ./saved_models/CAM1-Epoch-33-Loss-1.653383.pth
#
# Epoch: 34
# Train Loss: 6.815398290753365
# Val Loss: 1.9029955863952637
# Saved model: ./saved_models/CAM1-Epoch-34-Loss-1.902995.pth
#
# Epoch: 35
# Train Loss: 6.704050078988075
# Val Loss: 1.6341665387153625
# Saved model: ./saved_models/CAM1-Epoch-35-Loss-1.634166.pth
#
# Epoch: 36
# Train Loss: 6.117293581366539
# Val Loss: 2.387971930205822
# Saved model: ./saved_models/CAM1-Epoch-36-Loss-2.387971.pth
#
# Epoch: 37
# Train Loss: 6.296940177679062
# Val Loss: 1.6681866347789764
# Saved model: ./saved_models/CAM1-Epoch-37-Loss-1.668186.pth
#
# Epoch: 38
# Train Loss: 6.328512258827686
# Val Loss: 1.5580188781023026
# Saved model: ./saved_models/CAM1-Epoch-38-Loss-1.558018.pth
#
# Epoch: 39
# Train Loss: 6.35077466070652
# Val Loss: 2.200730100274086
# Saved model: ./saved_models/CAM1-Epoch-39-Loss-2.200730.pth
#
# Epoch: 40
# Train Loss: 5.582967892289162
# Val Loss: 2.667846232652664
# Saved model: ./saved_models/CAM1-Epoch-40-Loss-2.667846.pth
#
# Epoch: 41
# Train Loss: 5.94990848004818
# Val Loss: 1.963732123374939
# Saved model: ./saved_models/CAM1-Epoch-41-Loss-1.963732.pth
#
# Epoch: 42
# Train Loss: 5.560797020792961
# Val Loss: 2.1111778765916824
# Saved model: ./saved_models/CAM1-Epoch-42-Loss-2.111177.pth
#
# Epoch: 43
# Train Loss: 5.8146237432956696
# Val Loss: 2.104246497154236
# Saved model: ./saved_models/CAM1-Epoch-43-Loss-2.104246.pth
#
# Epoch: 44
# Train Loss: 5.449093535542488
# Val Loss: 1.9196043759584427
# Saved model: ./saved_models/CAM1-Epoch-44-Loss-1.919604.pth
#
# Epoch: 45
# Train Loss: 6.26223000138998
# Val Loss: 2.088951289653778
# Saved model: ./saved_models/CAM1-Epoch-45-Loss-2.088951.pth
#
# Epoch: 46
# Train Loss: 5.878534644842148
# Val Loss: 2.0932876989245415
# Saved model: ./saved_models/CAM1-Epoch-46-Loss-2.093287.pth
#
# Epoch: 47
# Train Loss: 5.360543582588434
# Val Loss: 1.6086155623197556
# Saved model: ./saved_models/CAM1-Epoch-47-Loss-1.608615.pth
#
# Epoch: 48
# Train Loss: 5.272310741245747
# Val Loss: 2.523480176925659
# Saved model: ./saved_models/CAM1-Epoch-48-Loss-2.523480.pth
#
# Epoch: 49
# Train Loss: 5.308772698044777
# Val Loss: 1.8885314166545868
# Saved model: ./saved_models/CAM1-Epoch-49-Loss-1.888531.pth
#
# Epoch: 50
# Train Loss: 5.3227716609835625
# Val Loss: 3.3330232053995132
# Saved model: ./saved_models/CAM1-Epoch-50-Loss-3.333023.pth
#
# Epoch: 51
# Train Loss: 5.813365645706654
# Val Loss: 1.6487153619527817
# Saved model: ./saved_models/CAM1-Epoch-51-Loss-1.648715.pth
#
# Epoch: 52
# Train Loss: 4.970142617821693
# Val Loss: 1.8528120815753937
# Saved model: ./saved_models/CAM1-Epoch-52-Loss-1.852812.pth
#
# Epoch: 53
# Train Loss: 4.908294267952442
# Val Loss: 2.283266454935074
# Saved model: ./saved_models/CAM1-Epoch-53-Loss-2.283266.pth
#
# Epoch: 54
# Train Loss: 5.1395169124007225
# Val Loss: 2.235787093639374
# Saved model: ./saved_models/CAM1-Epoch-54-Loss-2.235787.pth
#
# Epoch: 55
# Train Loss: 4.855200469493866
# Val Loss: 1.847258597612381
# Saved model: ./saved_models/CAM1-Epoch-55-Loss-1.847258.pth
#
# Epoch: 56
# Train Loss: 4.363677263259888
# Val Loss: 2.1779856383800507
# Saved model: ./saved_models/CAM1-Epoch-56-Loss-2.177985.pth
#
# Epoch: 57
# Train Loss: 4.590948447585106
# Val Loss: 1.4226020760834217
# Saved model: ./saved_models/CAM1-Epoch-57-Loss-1.422602.pth
#
# Epoch: 58
# Train Loss: 5.087772391736507
# Val Loss: 1.8356040120124817
# Saved model: ./saved_models/CAM1-Epoch-58-Loss-1.835604.pth
#
# Epoch: 59
# Train Loss: 4.730517074465752
# Val Loss: 2.7275211811065674
# Saved model: ./saved_models/CAM1-Epoch-59-Loss-2.727521.pth
#
# Epoch: 60
# Train Loss: 4.909461006522179
# Val Loss: 2.789988249540329
# Saved model: ./saved_models/CAM1-Epoch-60-Loss-2.789988.pth
#
# Epoch: 61
# Train Loss: 4.244837082922459
# Val Loss: 1.7906426712870598
# Saved model: ./saved_models/CAM1-Epoch-61-Loss-1.790642.pth
#
# Epoch: 62
# Train Loss: 4.068569831550121
# Val Loss: 1.8294669017195702
# Saved model: ./saved_models/CAM1-Epoch-62-Loss-1.829466.pth
# Epoch: 63
# Train Loss: 4.189759433269501
# Val Loss: 2.7191960513591766
# Saved model: ./saved_models/CAM1-Epoch-63-Loss-2.719196.pth
#
# Epoch: 64
# Train Loss: 4.3574953600764275
# Val Loss: 1.9749354124069214
# Saved model: ./saved_models/CAM1-Epoch-64-Loss-1.974935.pth
#
# Epoch: 65
# Train Loss: 4.990820974111557
# Val Loss: 2.381399154663086
# Saved model: ./saved_models/CAM1-Epoch-65-Loss-2.381399.pth
#
# Epoch: 66
# Train Loss: 4.260516904294491
# Val Loss: 2.240708351135254
# Saved model: ./saved_models/CAM1-Epoch-66-Loss-2.240708.pth
#
# Epoch: 67
# Train Loss: 4.4143234342336655
# Val Loss: 1.7654812037944794
# Saved model: ./saved_models/CAM1-Epoch-67-Loss-1.765481.pth
#
# Epoch: 68
# Train Loss: 4.176915533840656
# Val Loss: 2.600604683160782
# Saved model: ./saved_models/CAM1-Epoch-68-Loss-2.600604.pth
#
# Epoch: 69
# Train Loss: 4.185529071837664
# Val Loss: 4.964815437793732
# Saved model: ./saved_models/CAM1-Epoch-69-Loss-4.964815.pth
#
# Epoch: 70
# Train Loss: 4.502256162464619
# Val Loss: 2.242395654320717
# Saved model: ./saved_models/CAM1-Epoch-70-Loss-2.242395.pth
#
# Epoch: 71
# Train Loss: 5.085687160491943
# Val Loss: 2.404348313808441
# Saved model: ./saved_models/CAM1-Epoch-71-Loss-2.404348.pth
#
# Epoch: 72
# Train Loss: 4.72990944981575
# Val Loss: 2.1847131699323654
# Saved model: ./saved_models/CAM1-Epoch-72-Loss-2.184713.pth
#
# Epoch: 73
# Train Loss: 3.790380485355854
# Val Loss: 2.4908674359321594
# Saved model: ./saved_models/CAM1-Epoch-73-Loss-2.490867.pth
#
# Epoch: 74
# Train Loss: 3.7343670055270195
# Val Loss: 2.1272487342357635
# Saved model: ./saved_models/CAM1-Epoch-74-Loss-2.127248.pth
#
# Epoch: 75
# Train Loss: 3.7863595709204674
# Val Loss: 2.7070465832948685
# Saved model: ./saved_models/CAM1-Epoch-75-Loss-2.707046.pth
#
# Epoch: 76
# Train Loss: 3.984497144818306
# Val Loss: 1.8564247488975525
# Saved model: ./saved_models/CAM1-Epoch-76-Loss-1.856424.pth
#
# Epoch: 77
# Train Loss: 3.4412702471017838
# Val Loss: 2.6356527358293533
# Saved model: ./saved_models/CAM1-Epoch-77-Loss-2.635652.pth
#
# Epoch: 78
# Train Loss: 4.174799606204033
# Val Loss: 4.1717506647109985
# Saved model: ./saved_models/CAM1-Epoch-78-Loss-4.171750.pth
#
# Epoch: 79
# Train Loss: 3.7412208020687103
# Val Loss: 2.5640446841716766
# Saved model: ./saved_models/CAM1-Epoch-79-Loss-2.564044.pth
#
# Epoch: 80
# Train Loss: 3.495669212192297
# Val Loss: 2.0820160657167435
# Saved model: ./saved_models/CAM1-Epoch-80-Loss-2.082016.pth
#
# Epoch: 81
# Train Loss: 3.788510613143444
# Val Loss: 4.959436923265457
# Saved model: ./saved_models/CAM1-Epoch-81-Loss-4.959436.pth
#
# Epoch: 82
# Train Loss: 3.642410635948181
# Val Loss: 2.5455994606018066
# Saved model: ./saved_models/CAM1-Epoch-82-Loss-2.545599.pth
#
# Epoch: 83
# Train Loss: 3.4496340602636337
# Val Loss: 2.82599675655365
# Saved model: ./saved_models/CAM1-Epoch-83-Loss-2.825996.pth
#
# Epoch: 84
# Train Loss: 4.005912180989981
# Val Loss: 2.0758513808250427
# Saved model: ./saved_models/CAM1-Epoch-84-Loss-2.075851.pth
#
# Epoch: 85
# Train Loss: 4.885644964873791
# Val Loss: 3.4679936468601227
# Saved model: ./saved_models/CAM1-Epoch-85-Loss-3.467993.pth
#
# Epoch: 86
# Train Loss: 4.82902717590332
# Val Loss: 2.437125314027071
# Saved model: ./saved_models/CAM1-Epoch-86-Loss-2.437125.pth
#
# Epoch: 87
# Train Loss: 4.284566842019558
# Val Loss: 2.855172872543335
# Saved model: ./saved_models/CAM1-Epoch-87-Loss-2.855172.pth
#
# Epoch: 88
# Train Loss: 3.350782811641693
# Val Loss: 1.9788112342357635
# Saved model: ./saved_models/CAM1-Epoch-88-Loss-1.978811.pth
#
# Epoch: 89
# Train Loss: 3.291346900165081
# Val Loss: 2.9029641449451447
# Saved model: ./saved_models/CAM1-Epoch-89-Loss-2.902964.pth
#
# Epoch: 90
# Train Loss: 3.3501098304986954
# Val Loss: 2.8345397412776947
# Saved model: ./saved_models/CAM1-Epoch-90-Loss-2.834539.pth
#
# Epoch: 91
# Train Loss: 3.1801713593304157
# Val Loss: 2.43817001581192
# Saved model: ./saved_models/CAM1-Epoch-91-Loss-2.438170.pth
#
# Epoch: 92
# Train Loss: 4.5338894203305244
# Val Loss: 2.5879005789756775
# Saved model: ./saved_models/CAM1-Epoch-92-Loss-2.587900.pth
#
# Epoch: 93
# Train Loss: 4.443882301449776
# Val Loss: 2.2931091859936714
# Saved model: ./saved_models/CAM1-Epoch-93-Loss-2.293109.pth
#
# Epoch: 94
# Train Loss: 4.13947531580925
# Val Loss: 3.066114902496338
# Saved model: ./saved_models/CAM1-Epoch-94-Loss-3.066114.pth
#
# Epoch: 95
# Train Loss: 3.9617815911769867
# Val Loss: 3.243895500898361
# Saved model: ./saved_models/CAM1-Epoch-95-Loss-3.243895.pth
#
# Epoch: 96
# Train Loss: 3.944234423339367
# Val Loss: 2.5562764108181
# Saved model: ./saved_models/CAM1-Epoch-96-Loss-2.556276.pth
#
# Epoch: 97
# Train Loss: 3.2232259921729565
# Val Loss: 3.0139288306236267
# Saved model: ./saved_models/CAM1-Epoch-97-Loss-3.013928.pth
#
# Epoch: 98
# Train Loss: 3.0386995002627373
# Val Loss: 2.693269908428192
# Saved model: ./saved_models/CAM1-Epoch-98-Loss-2.693269.pth
#
# Epoch: 99
# Train Loss: 3.3362534549087286
# Val Loss: 2.5828341841697693
# Saved model: ./saved_models/CAM1-Epoch-99-Loss-2.582834.pth
#
#
# Finished Training

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax0 = plt.subplots(figsize=(9.6,7.2))
ax1 = ax0.twinx()
ax0.set_title("Train Loss & Val Loss")
ax0.plot(all_train_loss, 'rs--', label="Train Loss")
ax0.set_ylabel("Train Loss")
ax0.grid(False)
ax1.plot(all_val_loss, 'go--', label="Val Loss")
ax1.set_ylabel("Val Loss")
ax1.grid(False)
ax0.set_xlabel("Epoch")
plt.legend(loc=1)
plt.show()
